# %%
alumno = {
    'numero_cuenta':1234 ,
    'carrera':'ICO',
    'direccion' : {
        'calle': 'Rancho seco',
        'numero': 23
      },
    'telefonos': ['5512352897','5512352897']
    }

# %%
print(alumno['direccion']['calle'][3:6:1])
print(alumno['telefonos'])
print(alumno)
alumno['facultad'] = "Fes Aragon"
print(alumno)
# Out:
# cho
# ['5512352897', '5512352897']
# {'numero_cuenta': 1234, 'carrera': 'ICO ¿hay otra?', 'direccion': {'calle': 'Rancho seco', 'numero': 23}, 'telefonos': ['5512352897', '5512352897']}
# {'numero_cuenta': 1234, 'carrera': 'ICO ¿hay otra?', 'direccion': {'calle': 'Rancho seco', 'numero': 23}, 'telefonos': ['5512352897', '5512352897'], 'facultad': 'Fes Aragon'}

# %%
#if
edad = 20
if edad >= 18:
    print("Eres mayor de edad.")
else:
  print("Eres menor de edad.")

# %%
# if- elif - else
edad = 15
if edad < 13:
    print("Eres un niño.")
elif edad < 18:
    print("Eres un adolescente.")
else:
    print("Eres un adulto.")
# Out:
# Eres un adolescente.

# %%
# if-elif-elif
edad = 20
if edad < 13:
    print("Eres un niño.")
elif edad < 18:
    print("Eres un adolescente.")
elif edad < 30:
    print("Eres un joven adulto.")
# Out:
# Eres un joven adulto.

# %%
# For   for(int = 1 ; i<10 ; i++)

for i in range(1, 10, 1):
    print(i)

# %%
frutas = ['piña', 'pera', 'manzana', 'fresa', 'aguacate']
for numero in frutas:
    print(numero)

# %%
print("---------------")
for numero in frutas:
    if numero == "manzana":
        break   # ó continue
    print(numero)  # imprime la fruta
print("fin")
# Out:
# ---------------
# piña
# pera
# fin

# %%
tam = 0
while tam < 10 :
  print(tam)
  tam = int(input("Dame n numero: "))
print("Final")
# Out:
# 0
# Dame n numero9
# 9
# Dame n numero10
# Final
